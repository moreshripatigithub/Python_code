# %%
print('hai')

# %%
n=5
for i in range(1,n+1):
    for j in range(1,n+1):
        if i==j:     #i+j==n+1
            print('@',end=' ')
        elif i>j:    #i+j>n+1
            print('!',end=' ')
        else:
            print('#',end=' ')
    print()

# %%
n=5
for i in range(1,n+1):
    for j in range(1,n+1):
        if i==1 or i==n or j==1 or j==n:
            print('@',end=' ')
        else:
            print(' ',end=' ')
    print()

# %%
n=5
for i in range(1,n+1):
    for j in range(1,n+1):
        if i==j or i==n//2+1 or (j==1 and i<=n//2+1) or (j==n and i>=n//2+1): # i==n//2+1 or j==n//2+1
            print('#',end=' ')
        else:
            print(' ',end=' ')
    print()

# %%
n=5
for i in range(1,n+1):
    k=1   # k=ord('A')
    for j in range(1,n+1):
        if i>=j:
            print(k,end=' ')     # print(chr(k),end=' )
            k+=1
        else:
            print(' ',end=' ')
    print()

# %%
n=5
for i in range(1,n+1):
    for s in range(1,n-i+1):
        print(' ',end=' ')
    for j in range(1,i+1):
        print('@',end='   ')
    print()

# %%
#reverse the no
n=123
res=0
while n!=0:
    ld=n%10
    n=n//10
    res=res*10+ld
print(res)

# %%
# reverse the given string
st = 'ashr'
res=''
for i in st:
    res=i+res
print(res)

# %%
#check given string is palindrom or not
st='shri'
var=st.lower()
res=st[::-1]
if var==res:
    print('palindrom')
else:
    print('not_palindrom')

# %%
#check given no is palindrom or not
n=123
res=0
temp=n
while n!=0:
    ld=n%10
    n=n//10
    res=res*10+ld
if temp==res:
    print('palindrom')
else:
    print('not palindrom')

# %%
# Print palindrome numbers between 100 and 150

for i in range(100,150):
    if str(i)==str(i)[::-1]:
        print(i)

# %%
#extract the even no
a = [1,2,3,40]
ev=[]
for i in a:
    if i%2==0:
        ev.append(i)
print(ev)

# %%
# if no is string than how to extract odd no 

a = ['1','2','3','400']
aa = [int(i) for i in a]
odd = []
for i in aa:
    if i%2!=0:
        odd.append(i)
print(odd)

# %%
#seperate all upper lower and no

st = 'ssWW123@!@'
u,l,n,ss = '','','',''
for i in st:
    if 'A'<=i<='Z':
        u+=i
    elif 'a'<=i<='z':
        l+=i
    elif '0'<=i<='9':
        n+=i
    else:
        ss+=i
print(u,l,n,ss)  # print('upper':,u,'lower':,l,'no':,n,'special':,ss)

# %%
# remove dub from list

a = [1,2,3,4,3,2,1]
res=[]
for i in a:
    if i not in res:
        res.append(i)
print(res)

# %%
# remove the dublicate from string

st ='ssshhrii'
nb=''
for i in st:
    if i not in nb:
        nb+=i
print(nb)

# %%
# remove dub but make sure ascending wise

a = [1,200,2,1,2,3,2,4,56]
a.sort()  # a.sort(reverse=True)
nb=[]
for i in a:
    if i not in nb:
        nb.append(i)
print(nb)

# %%
# extract no from string

st = 'fheru34939'
no=''
for i in st:
    if '0'<=i<='9':
        no+=i
print(no)

# %%
# add between 1 to 10
m,n=1,10
su=0
for i in range(m,n):
    su+=i
print(su)

# %%
# add between list

a=[1,2,3,4,5]
su=0
for i in a:
    su+=i
print(su)

# %%
# print saqure of list

a = [1,2,3,4]
res=[]
for i in a:
    res.append(i*i)
print(res)

# %%
# print smallest divisor of given no
n=123
for i in range(2,n):
    if n%i==0:
        print(i)

# %%
# check wheater given string is only alph or not
st ='fvej2f'
flag=0
for i in st:
    if 'a'<=i<='z' or 'A'<=i<='Z':
        flag=1
        break
    if flag==0:
        print('yes')
    else:
        print(no)

# %%
#  extract the no which is presenyt at odd position

a = [1,2,3,4,5,6,6,8,8,90]
odd=[]
for i in range(0,len(a)):
    if i%2!=0:
        odd.append(a[i])
print(odd)

# %%
# print the index of given aplfabets

st='shri'
ch='i'
for i in range(0,len(st)):
    if st[i]==ch:
        print(i)

# %%
# print the all index at time

st ='shriiser'
res={}
for i in range(0,len(st)):
    if st[i] not in res:
        res[st[i]]=i
print(res)

# %%
# for all recors if it get repeted than also

st = 'shrettis'
res={}
for i in range(0,len(st)):
    if st[i] not in res:
        res[st[i]] = [i]
    else:
        res[st[i]].append(i)
print(res)

# %%
st = 'sshrisi'
res={}
for i in range(0,len(st)):
    if st[i] not in res:
        res[st[i]] = [i]
    else:
        res[st[i]].append(i)
print(res)

# %%
# convert upper to lower
st = 'shri'
res=''
for i in st:
    if 'A'<=i<='Z':
        res+=chr(ord(i)+32)
    else:
        res+=chr(ord(i)-32)
print(res)

# %%
# check given no is prime or not

n=7
flag=0
for i in range(2,n):
    if n%i==0:
        blag=1
        break
if flag==0:
    print('prime')
else:
    print('not prime')

# %%
# print prime no between 2 to  15

m=2
n=15
while m<n:
    flag=0
    for i in range(2,m):
        if m%i==0:
            flag=1
            break
    if flag==0:
        print(m)
    m+=1

# %%
# print 15 prime no
m=2
n=15
c=0
while c<n:
    flag=0
    for i in range(2,m):
        if m%i==0:
            flag=1
            break
    if flag==0:
        print(m)
        c+=1
    m+=1

# %%
# check given not armstrong or not
n=123
N=len(str(n))
temp=n
res=0
while n!=0:
    ld=n%10
    n=n//10
    res==ld**N
if temp==res:
    print('arm')
else:
    print('no_arm')

# %%
# count how many times s was repeated in string

st = 'ssshrrsss'
ch='s'
c=0
for i in st:
    if i==ch:
        c+=1
print(c)

# %%
# count how many times 1 was repeated in list

a = [1,2,3,4,5,6,7,1,1,2,1,2,1]
ch = 2
c=0
for i in a:
    if i==ch:
        c+=1
print(c)

# %%
# count everything at a time for list

a = [1,2,3,2,1,2,3,42]
res={}
for i in a:
    if i not in res:
        res[i]=a.count(i)
print(res)

# %%
# count everything at a time for string

st = 'shrrri'
res={}
for i in st:
    if i not in res:
        res[i]=st.count(i)
print(res)

# %%
import re
st = "hello!! this is a hello?!"
st=st.lower()
st = re.sub(r'[^a-z0-9\s]','',st)
var = st.split()
res={}
for i in var:
    if i not in res:
        res[i] = res.get(i,0)+1
print(res)

# %%
# crate dict from list
a=['a','b']
b=[1,2]
res= {}
if len(a)!=len(b):
    print('not_possible')
else:
    for i in range(0,len(a)):
        res[a[i]]=b[i]
print(res)

# %%
# extract keys and value
d = {'a': 1, 'b': 2}
k=[]
v=[]
for i in d:
    k+=[i]
    v+=[d[i]]
print(k)
print(v)

# %%
#splite the value from dict

d = {'a': 1, 'b': 2}
k=list(d)
v=list(d.values())
res={}
for i in range(0,len(k)):
    res[v[i]]=k[i]
print(res)

# %%
# finds the value of 'a'

st = 'Aa'
res=0
for i in st:
    if 'a'<=i<='z':
        res+=ord(i)
print(res)

# %%
# remove the speces
st = 's h r i'
res=''
for i in st:
    if (not i.isspace()):
        res+=i
print(res)

# %%
# just extract the value from string

l=['rs.3','rs.4']
res=[]
for i in l:
    i=i.replace('rs.','')
    res.append(int(i))
print(res)

# %%
# check both string ang or not

def check(s1,s2):
    if sorted(s1)==sorted(s2):
        return True
    else:
        return False
s1='shri'
s2='shri'
print(check(s1,s2))

# %%
# print fibonicial series
def f(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return f(n-1)+f(n-2)

for i in range(11):
    print(f(i))
